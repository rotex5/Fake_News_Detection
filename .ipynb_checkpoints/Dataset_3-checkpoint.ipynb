# %% [markdown]
# # Fake News Detection USing Dataset 3

# %%
import numpy as np
import pandas as pd
import re,string,unicodedata
import os

# NLP Libs
import nltk
from nltk.corpus import stopwords
#from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
#from bs4 import BeautifulSoup

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Import our data

fake = pd.read_csv("./dataset/ISOT_News_dataset/Fake.csv")
true = pd.read_csv("./dataset/ISOT_News_dataset/True.csv")

# %%
true.sample(20)
# Out:
#                                                    title  \
# 730    U.S. firm Air Products, China's Yankuang plan ...
# 14400  Macron says not in French interests for German...
# 13024  U.S. plan to move Israel embassy sign of 'fail...
# 11194  Republican Jeb Bush offers U.S. education over...
# 16975  Lebanon's parliament approves country's first ...
# 9152   Obama to travel to Orlando on Thursday: White ...
# 4130   U.S. will not give Exxon permission to drill i...
# 8047   Most Clinton emails to be released after elect...
# 3440   Kremlin says Paris climate deal unworkable wit...
# 2192   Texas 'bathroom bills' stall in special legisl...
# 5978   Mattis stresses commitment to NATO to German d...
# 19300  Britain says Moody's downgrade based on 'outda...
# 3530   Exclusive: Tillerson declines to host Ramadan ...
# 3788   Trump administration vastly expands global ant...
# 6913   Factbox: Trump to meet this week with U.S. law...
# 8849   U.S. Republicans reject Democratic funding pro...
# 3984   U.S. Congress secures health benefits for coal...
# 15212  UK's May picks Brexiteer to replace scandal-hi...
# 1191   Trump favors ex-pharma executive Azar for heal...
# 10240  White House opposes bill it says harms FTC con...
#
#                                                     text       subject  \
# 730    BEIJING (Reuters) - A top Chinese coal miner, ...  politicsNews
# 14400  PARIS (Reuters) - President Emmanuel Macron sa...     worldnews
# 13024  BEIRUT (Reuters) - U.S. plans to move its Isra...     worldnews
# 11194  WASHINGTON (Reuters) - Republican presidential...  politicsNews
# 16975  BEIRUT (Reuters) - Lebanon s parliament on Thu...     worldnews
# 9152   WASHINGTON (Reuters) - President Barack Obama ...  politicsNews
# 4130   WASHINGTON/SPRING, Tx. (Reuters) - The United ...  politicsNews
# 8047   WASHINGTON (Reuters) - Most of the emails the ...  politicsNews
# 3440   MOSCOW (Reuters) - The Paris climate deal is u...  politicsNews
# 2192   AUSTIN, Texas (Reuters) - Texas measures to re...  politicsNews
# 5978   WASHINGTON (Reuters) - Defense Secretary James...  politicsNews
# 19300  LONDON (Reuters) - Britain s government said o...     worldnews
# 3530   WASHINGTON (Reuters) - Secretary of State Rex ...  politicsNews
# 3788   WASHINGTON (Reuters) - The Trump administratio...  politicsNews
# 6913   (Reuters) - U.S. Republican President-elect Do...  politicsNews
# 8849   WASHINGTON (Reuters) - Republican lawmakers in...  politicsNews
# 447    Believe or not,  moderates  do exist in the Re...             News
# 5641   Comedian Denis Leary has donated a lot of his ...             News
# 19887   In a lame effort to score political points fo...        left-news
# 9498   The move by a Twitter employee last week to ba...         politics
# 16157  Zinke and Brandyburg accompanied Spicer to the...  Government News
# 16294  EXCLUSIVE: FBI New York Field Office Told To C...  Government News
# 5992   Being transgender in a society that does not u...             News
# 8260   The Republican Party s establishment candidate...             News
#
#                                                     date
# 7453                                      March 17, 2016
# 17562                                        Dec 6, 2017
# 18305                                       Jul 17, 2017
# 7101                                       April 4, 2016
# 20522                                       May 25, 2016
# 15840  https://fedup.wpengine.com/wp-content/uploads/...
# 11966                                        Jan 8, 2017
# 14942                                       Nov 11, 2015
# 19270                                       Jan 21, 2017
# 12910                                       Sep 26, 2016
# 16785                                        Feb 5, 2016
# 14718                                        Jan 2, 2016
# 447                                    September 2, 2017
# 5641                                        July 2, 2016
# 19887                                        Oct 2, 2016
# 9498                                         Nov 6, 2017
# 16157                                        Apr 3, 2017
# 16294                                       Dec 15, 2016
# 5992                                        June 6, 2016
# 8260                                    February 8, 2016

# %%
true.shape,fake.shape
# Out:
# ((21417, 4), (23481, 4))

# %%
# These dataframes do not currently have a category for whether they are true or fake.
# Let's create those before we combine the datasets

fake['label'] = 1
true['label'] = 0

# %%
# Now we'll merge the two datasets into a single dataframe

df = pd.concat([true,fake])

# %%
df.sample(10)
# Out:
#                                                    title  \
# 17229  SHOCKING: Interviewer Shows Many Americans Hav...
# 14358  WATCH: RONALD REAGAN WARNED US ABOUT OBAMA 40 ...
# 9492   Clinton begins Appalachia tour in Trump-friend...
# 19394  Mexicans respond with faith and charity as hop...
# 17434   (VIDEO) OBAMA THROWS AMERICA UNDER THE BUS…AGAIN
# 322     Golden State Warriors Coach Just WRECKED Trum...
# 8173    WATCH: Harney County Trio Releases ‘Ballad Of...
# 7344   Trump strongly considering naming campaign chi...
# 19455  WOMEN IN FRANCE Fight Back After Muslim Men BA...
# 1381   Factbox: Trump on Twitter (Oct 5) - Ralph Nort...
#
#                                                     text          subject  \
# 17229  The dumbing down of America This is how people...  Government News
# 14358  This video needs to be shared over and over ag...         politics
# 9492   WASHINGTON (Reuters) - U.S. Democratic preside...     politicsNews
# 19394  MEXICO CITY (Reuters) - Tears flowed at Our La...        worldnews
# 17434   I am a student of history so I tend to actual...  Government News
# 322    On Saturday, the man we re forced to call  Pre...             News
# 8173   As the 41 day standoff between federal officia...             News
# 7344   WASHINGTON (Reuters) - President-elect Donald ...     politicsNews
# 19455  These women aren t sitting back and waiting fo...        left-news
# 1381   The following statements were posted to the ve...     politicsNews
#
#                       date  label
# 17229          Jul 3, 2015      1
# 14358          Mar 6, 2016      1
# 9492          May 2, 2016       0
# 19394  September 22, 2017       0
# 17434         Apr 12, 2015      1
# 322     September 24, 2017      1
# 8173     February 12, 2016      1
# 7344    November 10, 2016       0
# 19455         Dec 13, 2016      1
# 1381      October 6, 2017       0

# %%
# Visualization Libs
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(16,9))

#sns.countplot(df.label)
sns.countplot(data=df, x='label')

plt.title('Total Fake and Real News Articles', fontsize=24)
plt.ylabel('Total', fontsize=16)
plt.xlabel('')
plt.xticks([1, 0], ['Fake', 'Real'], fontsize=16)

plt.show()

# %%
df.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'label'], dtype='object')

# %%
print(df.isnull().sum())
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
df.sample(10)
# Out:
#                                                    title  \
# 14328  YIKES! 46,000 DEMOCRATS In Important Blue Stat...
# 14306  AUSTRIAN Schools Are Being Radicalized By Youn...
# 15232  IN A RULING THAT WILL MAKE OBAMA’S HEAD SPIN, ...
# 22441  FOX News Anchor Shepard Smith Finally ‘Comes O...
# 161     WATCH: Hannity Loses His Sh*t And Refers To H...
# 11930  Valerie Jarrett Gives Most Hateful Exit Interv...
# 14676  Lebanon's president says crisis over with PM H...
# 5945   Trump says Mexican imports tax one option but ...
# 4974   Republican plan to repeal Obamacare would leav...
# 11115  ANTI-TRUMP Communications Specialist For UN Ar...
#
#                                                     text       subject  \
# 14328  This is a state that hasn t always been reliab...      politics
# 14306  This story is a perfect example of how Muslim ...      politics
# 15232  Another victory for one of the most bad ass Sh...      politics
# 22441  21st Century Wire says For many viewers, this ...       US_News
# 161    Sean Hannity threw a massive temper tantrum on...          News
# 11930                                                         politics
# 14676  BEIRUT (Reuters) - Lebanese President Michel A...     worldnews
# 5945   WASHINGTON (Reuters) - U.S. President Donald T...  politicsNews
# 4974    (In March 13 item, corrects paragraph 7 to sh...  politicsNews
# 11115  A United Nations employee was busted for robbi...      politics
#
#                      date  label
# 14328        Mar 11, 2016      1
# 14306        Mar 13, 2016      1
# 15232         Sep 5, 2015      1
# 22441    October 18, 2016      1
# 161      October 31, 2017      1
# 11930        Jan 12, 2017      1
# 14676  November 16, 2017       0
# 5945    January 27, 2017       0
# 4974      March 13, 2017       0
# 11115        Apr 18, 2017      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44898 entries, 0 to 23480
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   label    44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 3.1+ MB

# %%
df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       0
# 1  December 29, 2017       0
# 2  December 31, 2017       0
# 3  December 30, 2017       0
# 4  December 29, 2017       0

# %%
# Now we'll create the Corpus that will be used in our NLP model

# This will create a single column with all the relevant text

df['total']=df['title']+' '+df['text']

# %%
df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label  \
# 0  December 31, 2017       0
# 1  December 29, 2017       0
# 2  December 31, 2017       0
# 3  December 30, 2017       0
# 4  December 29, 2017       0
#
#                                                total
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...

# %%
df = df.drop(['title','text','subject', 'date'],axis = 1)

# %%
df.head()
# Out:
#    label                                              total
# 0      0  As U.S. budget fight looms, Republicans flip t...
# 1      0  U.S. military to accept transgender recruits o...
# 2      0  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      0  FBI Russia probe helped by Australian diplomat...
# 4      0  Trump wants Postal Service to charge 'much mor...

# %% [markdown]
# # Cleaning and preprocessing

# %%
stop_words = stopwords.words('english')
lemmatizer=WordNetLemmatizer()
for index,row in df.iterrows():
    filter_sentence = ''

    sentence = row['total']
    sentence = re.sub(r'[^\w\s]','',sentence) #cleaning
    words = nltk.word_tokenize(sentence) #tokenization
    words = [w.lower() for w in words if not w in stop_words]  #stopwords removal

    for word in words:
        filter_sentence = filter_sentence + ' ' + str(lemmatizer.lemmatize(word)).lower()

    df.loc[index,'total'] = filter_sentence

# %%
from sklearn.utils import shuffle

df = shuffle(df, random_state=42)
df.head()
# Out:
#        label                                              total
# 799        1   breaking gop chairman grassley ha had enough ...
# 6500       1   failed gop candidate remembered in hilarious ...
# 3590       1   mike pences new dc neighbor are hilariously t...
# 1377       0   oops trump just accidentally confirmed he lea...
# 11059      1   az rancher living on usmexico border destroy ...

# %%
df.to_csv("./dataset/ISOT_News_dataset/cleaned_dataset_2.csv")
